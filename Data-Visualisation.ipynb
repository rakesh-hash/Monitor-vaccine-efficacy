# %%
import pandas as pd
data = pd.read_csv('C:/Users/Shiva Padmaja/Downloads/tests_day_wise.csv')
data
# Out:
#        Update Time Stamp Tested As Of  Total Samples Tested  \
# 0    13/03/2020 00:00:00   13/03/2020                6500.0
# 1    18/03/2020 18:00:00   18/03/2020               13125.0
# 2    19/03/2020 10:00:00   19/03/2020               13316.0
# 3    19/03/2020 18:00:00   19/03/2020               14175.0
# 4    20/03/2020 10:00:00   20/03/2020               14376.0
# ..                   ...          ...                   ...
# 144  02/08/2020 09:00:00   01/08/2020            19821831.0
# 145  03/08/2020 09:00:00   02/08/2020            20202858.0
# 146  04/08/2020 09:00:00   03/08/2020            20864750.0
# 147  05/08/2020 09:00:00   04/08/2020            21484402.0
# 148  06/08/2020 09:00:00   05/08/2020            22149351.0
#
#      Total Individuals Tested Total Positive Cases  \
# 0                      5900.0                   78
# 1                     12235.0                  150
# 2                     12426.0                  168
# ...

# %%
data.plot()

# %%
data = pd.read_csv('C:/Users/Shiva Padmaja/Downloads/State_wise_and_district_wise_population_density.csv')
data
# Out:
#                          State                    District  \
# 0    Andaman & Nicobar Islands                     Nicobar
# 1    Andaman & Nicobar Islands      North & Middle Andaman
# 2    Andaman & Nicobar Islands               South Andaman
# 3               Andhra Pradesh                   Anantapur
# 4               Andhra Pradesh                    Chittoor
# ..                         ...                         ...
# 635                West Bengal           Paschim Medinipur
# 636                West Bengal             Purba Medinipur
# 637                West Bengal          Puruliya (Purulia)
# 638                West Bengal  South Twenty Four Parganas
# 639                West Bengal              Uttar Dinajpur
#
#      Population in 2001  Population in 2011
# 0                 42068               36842
# 1                105613              105597
# 2                208471              238142
# 3               3640478             4081148
# ...

# %%
data.plot()

# %%
data = pd.read_csv('C:/Users/Shiva Padmaja/Downloads/Covid-19_cases_district_and_state_level.csv')
data
# Out:
#      SlNo State_Code                        State  \
# 0       0         UN             State Unassigned
# 1       1         AN  Andaman and Nicobar Islands
# 2       2         AN  Andaman and Nicobar Islands
# 3       3         AN  Andaman and Nicobar Islands
# 4       0         AP               Andhra Pradesh
# ..    ...        ...                          ...
# 795   760         TG                    Telangana
# 796   761         TR                      Tripura
# 797   762         UP                Uttar Pradesh
# 798   763         UT                  Uttarakhand
# 799   764         WB                  West Bengal
#
#                     District_Key                  District  Confirmed  Active  \
# 0                  UN_Unassigned                Unassigned          0       0
# 1                    AN_Nicobars                  Nicobars          0       0
# 2    AN_North and Middle Andaman  North and Middle Andaman          1       0
# ...

# %%
data.plot()

# %%
data = pd.read_csv('C:/Users/Shiva Padmaja/Downloads/Covid-19_cases_day_wise.csv')
data
# Out:
#       Unnamed: 0       Date State  Confirmed  Deceased  Recovered  \
# 0              0  01-Apr-20    AN          0         0          0
# 1              1  01-Apr-20    AP         67         0          1
# 2              2  01-Apr-20    AR          0         0          0
# 3              3  01-Apr-20    AS         15         0          0
# 4              4  01-Apr-20    BR          3         0          0
# ...          ...        ...   ...        ...       ...        ...
# 5689        5689  31-May-20    TT       8789       222       4928
# 5690        5690  31-May-20    UN        448         0          0
# 5691        5691  31-May-20    UP        374         4        192
# 5692        5692  31-May-20    UT        158         0          0
# 5693        5693  31-May-20    WB        371         8        187
#
#                        State_Name
# 0     Andaman and Nicobar Islands
# 1                  Andhra Pradesh
# 2               Arunachal Pradesh
# ...

# %%
data.plot()
